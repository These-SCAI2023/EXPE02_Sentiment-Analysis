# %% [markdown]
# # French sentiment analysis with BERT

# %% [markdown]
# This notebook acts as an online demo for [this repository](https://github.com/TheophileBlard/french-sentiment-analysis-with-bert).
#
# With this notebook, you can perform inference on your own sentences.
# You cannot train the model, to do so, please clone the repo.
#
# *This is still experimental, so let me know if something doesn't work !*
#
# **Author**: Théophile Blard ([LinkedIn](https://www.linkedin.com/in/theophile-blard))

# %% [markdown]
# ## Preliminary steps

# %%
# !pip install tensorflow==2.12.0 transformers==4.30.2 notebook
# Out:
# Requirement already satisfied: tensorflow==2.12.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (2.12.0)
# Requirement already satisfied: transformers==4.30.2 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (4.30.2)
# Requirement already satisfied: notebook in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (7.5.3)
# Requirement already satisfied: absl-py>=1.0.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (25.12.19)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from tensorflow==2.12.0) (1.76.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from tensorflow==2.12.0) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (3.4.0)
# Requirement already satisfied: packaging in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from tensorflow==2.12.0) (3.20.3)
# Requirement already satisfied: setuptools in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (68.2.0)
# Requirement already satisfied: six>=1.12.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorflow==2.12.0) (4.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from tensorflow==2.12.0) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from tensorflow==2.12.0) (0.37.1)
# Requirement already satisfied: filelock in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from transformers==4.30.2) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from transformers==4.30.2) (0.36.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from transformers==4.30.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from transformers==4.30.2) (2026.1.15)
# Requirement already satisfied: requests in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from transformers==4.30.2) (2.32.5)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from transformers==4.30.2) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from transformers==4.30.2) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from transformers==4.30.2) (4.67.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from notebook) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from notebook) (2.28.0)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.3 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from notebook) (4.5.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from notebook) (6.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow==2.12.0) (0.41.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.2) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.2) (1.2.0)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.5.4)
# Requirement already satisfied: scipy>=1.9 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from jax>=0.3.15->tensorflow==2.12.0) (1.13.1)
# Requirement already satisfied: importlib-metadata>=4.6 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow==2.12.0) (8.7.1)
# Requirement already satisfied: anyio>=3.1.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.12.1)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.17.0)
# Requirement already satisfied: nbformat>=5.3.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.24.1)
# Requirement already satisfied: pyzmq>=24 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyterlab<4.6,>=4.5.3->notebook) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyterlab<4.6,>=4.5.3->notebook) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyterlab<4.6,>=4.5.3->notebook) (6.31.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyterlab<4.6,>=4.5.3->notebook) (2.3.0)
# Requirement already satisfied: tomli>=1.2.2 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyterlab<4.6,>=4.5.3->notebook) (2.4.0)
# Requirement already satisfied: babel>=2.10 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.25.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from requests->transformers==4.30.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from requests->transformers==4.30.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from requests->transformers==4.30.2) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from requests->transformers==4.30.2) (2026.1.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.48.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.1.5)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (46.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.0.0)
# Requirement already satisfied: httpcore==1.* in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.3->notebook) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.3->notebook) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from importlib-metadata>=4.6->jax>=0.3.15->tensorflow==2.12.0) (3.23.0)
# Requirement already satisfied: comm>=0.1.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (8.18.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (7.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.27.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.4.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.14.3)
# Requirement already satisfied: bleach[css]!=5.0.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.2.0)
# Requirement already satisfied: defusedxml in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.19.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.2)
# Requirement already satisfied: ptyprocess in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook) (0.7.0)
# Requirement already satisfied: webencodings in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (from cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.0.0)
# Requirement already satisfied: decorator in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (3.0.52)
# Requirement already satisfied: stack-data in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (4.9.0)
# Requirement already satisfied: fqdn in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (24.11.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.6.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.3.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8.3)
# Requirement already satisfied: pycparser in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.23)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (0.8.5)
# Requirement already satisfied: wcwidth in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (0.5.3)
# Requirement already satisfied: lark>=1.2.2 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from rfc3987-syntax>=1.1.0->jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (1.4.0)
# Requirement already satisfied: executing>=1.2.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (3.0.1)
# Requirement already satisfied: pure-eval in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.3->notebook) (0.2.3)
# Requirement already satisfied: tzdata in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.3)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install transformers>=4.0
# !pip install sentencepiece
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: sentencepiece in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (0.2.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install protobuf==3.20.3 sentencepiece
# Out:
# Requirement already satisfied: protobuf==3.20.3 in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (3.20.3)
# Requirement already satisfied: sentencepiece in /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib64/python3.9/site-packages (0.2.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# *Please run these cells, otherwise inference won't work.*

# %%
import tensorflow as tf
assert tf.__version__ >= "2.0"
# Out:
# 2026-03-19 17:25:59.370151: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-19 17:25:59.865362: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-19 17:26:00.489878: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-19 17:26:00.490593: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-19 17:26:05.554905: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("tblard/tf-allocine", use_fast=True)
model = TFAutoModelForSequenceClassification.from_pretrained("tblard/tf-allocine")

nlp = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)
# Out:
# /home/caroline/Documents/EXPE_2025/EXPE02_Sentiment-Analysis/.nervavenv/lib/python3.9/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/811k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/210 [00:00<?, ?B/s]
# tf_model.h5:   0%|          | 0.00/445M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFCamembertForSequenceClassification.
#
# All the layers of TFCamembertForSequenceClassification were initialized from the model checkpoint at tblard/tf-allocine.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFCamembertForSequenceClassification for predictions without further training.

# %%
text = input("Enter text: ")
result = nlp(text)
prediction = result[0]["label"]
print(prediction)
# Out:
# POSITIVE

# %% [markdown]
# # Exercice

# %% [markdown]
# En vous inspirant du programme sentanaly_distill.py utiliser les textes du corpus pour prédire si les phrases sont poitives où négatives
